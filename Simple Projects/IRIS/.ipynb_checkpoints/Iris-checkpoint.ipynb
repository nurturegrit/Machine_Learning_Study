# %% [markdown]
# ## This project will cover:
#
#    * Understanding the problem
#    * Loading and exploring the data
#    * Preprocessing the data
#    * Building and training a machine learning model
#    * Evaluating the model
#    * Making predictions with the model

# %% [markdown]
# ## Understanding the Problem
#
# The Iris dataset is a classic dataset in machine learning and statistics, consisting of measurements of various features of three different species of Iris flowers (Setosa, Versicolour, and Virginica). The goal is to classify these species based on the given features.
# Dataset Features
#
#     Sepal length (in cm)
#     Sepal width (in cm)
#     Petal length (in cm)
#     Petal width (in cm)
#     Species (target variable)

# %% [markdown]
#     Pandas and NumPy for data manipulation
#     Scikit-learn for building the machine learning model
#     Matplotlib and Seaborn for data visualization

# %% [markdown]
# First, let's load the Iris dataset and take a look at the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Load the Iris dataset

# %%
iris = pd.read_csv('iris.csv')

# %% [markdown]
# # Create a DataFrame

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### A Balanced Dataset - The Class Labels are in same propotions
# -- WE HAVE TO DO SLIGHTLY DIFFERENT ANAYLSIS FOR UNBALANCED DATSETS

# %% [markdown]
# ## 2-D Scatter Plot

# %%
iris.plot(kind="scatter", x="sepal_length", y="sepal_width");
plt.show()

# %% [markdown]
# Note : TTHE ORIGIN IS NOT (0,0) !
# When we see a plot,
# it is important to read the
# * scale and range of x and y axis
# * legend
# * x and y axis labels of the plot
# * origin

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue="species", height=4) \
    .map(plt.scatter, "sepal_length", "sepal_width") \
    .add_legend();
plt.show()

# %% [markdown]
# OBSERVATION(s) :
# * USING sepal_length and sepal_width features, we can distinguish `Setosa` flowers from others.
# * Seperating Versicolor and Virginica is much harder as they have considerable overlap.

# %% [markdown]
# # 3 D Scatter Plot

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a scatter plot for each species
species = iris['species'].unique()
colors = ['r', 'g', 'b']
for i, s in enumerate(species):
    species_data = iris[iris['species'] == s]
    ax.scatter(species_data['sepal_length'], species_data['sepal_width'], 
               species_data['petal_length'], c=colors[i], label=s)

# Set labels and title
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
ax.set_title('3D Scatter Plot of Iris Dataset')

# Add a legend
ax.legend()

# Show the plot
plt.ion()  # Turn on interactive mode
plt.show()

# %% [markdown]
# # Pair Plots - to visualize more dimensions

# %%
# pairwise scatter plot: Pair plot
# Dis-advantages:
## Can be Used when number of features are high
## Cannot directly visualize higher dimensional patterns in 3d and 4d
plt.close()
sns.pairplot(iris, hue="species", height=4)
plt.show()
# Diagnol Elements are PDF for each feature, {DF are explained ahead.

# %% [markdown]
# # Observations:
# * We can see through the above plot that petal_length and petal_width are the most important deatures in our dataset to get to our objective.
# * The Setosa Flower Species is Linearily Seperable from Other Species.
# * Versicolor and Virginica Species have some overlap (almost linearily sperable).
# * Hence we can make a simple model for Iris Dataset using if-else statements.

# %% [markdown]
# # Histogram, PDF, CDF

# %% [markdown]
# # Display the first few rows of the DataFrame
# print(df.head())
#
# # Display basic statistics
# print(df.describe())
#
# Step 3: Visualizing the Data
#
# (Optional) Let's visualize the data to better understand it. This can be done using Matplotlib or Seaborn.
#
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Pairplot to visualize relationships between features
# sns.pairplot(df, hue='species')
# plt.show()
#
# Step 4: Preprocessing the Data
#
# Before building the machine learning model, we'll split the data into features (X) and labels (y), and then into training and testing sets.
#
# from sklearn.model_selection import train_test_split
#
# # Features and labels
# X = df.drop('species', axis=1)
# y = df['species']
#
# # Split the data into training and testing sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# Step 5: Building and Training the Model
#
# We'll use a simple machine learning algorithm called K-Nearest Neighbors (KNN) for this task.
#
# from sklearn.neighbors import KNeighborsClassifier
#
# # Create the model
# knn = KNeighborsClassifier(n_neighbors=3)
#
# # Train the model
# knn.fit(X_train, y_train)
#
# Step 6: Evaluating the Model
#
# Now, we'll evaluate the model's performance using the test data.
#
# from sklearn.metrics import accuracy_score, classification_report
#
# # Make predictions
# y_pred = knn.predict(X_test)
#
# # Evaluate accuracy
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {accuracy}")
#
# # Detailed classification report
# print(classification_report(y_test, y_pred))
#
# Step 7: Making Predictions
#
# Finally, let's use our trained model to make predictions on new data.
#
# # Example new data (can be changed to test)
# new_data = [[5.1, 3.5, 1.4, 0.2]]
#
# # Make a prediction
# prediction = knn.predict(new_data)
# print(f"Predicted species: {iris.target_names[prediction][0]}")
#
# Conclusion
#
# That's it! You've just built a basic machine learning model for classifying Iris flowers. From here, you can explore further by trying different algorithms, tuning hyperparameters,
